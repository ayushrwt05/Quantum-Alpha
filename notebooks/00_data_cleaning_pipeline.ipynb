# %%
import pandas as pd

df = pd.read_csv("market_multi_asset.csv")

df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2025 entries, 0 to 2024
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               2025 non-null   object
#  1   nifty_close        2025 non-null   float64
#  2   nifty_ret          2024 non-null   float64
#  3   bank_close         2025 non-null   float64
#  4   bank_ret           2025 non-null   float64
#  5   relative_strength  2024 non-null   float64
#  6   breadth_signal     2015 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 110.9+ KB
#         nifty_close    nifty_ret    bank_close     bank_ret  \
# count   2025.000000  2024.000000   2025.000000  2025.000000
# mean   16936.117990     0.000451  38252.359555     0.000467
# std     5313.853399     0.010732  11091.659831     0.014232
# min     7610.250000    -0.129805  16917.453125    -0.167340
# 25%    11557.099609    -0.004484  28653.365234    -0.005927
# ...

# %%
df = df.dropna()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2015 entries, 10 to 2024
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               2015 non-null   object
#  1   nifty_close        2015 non-null   float64
#  2   nifty_ret          2015 non-null   float64
#  3   bank_close         2015 non-null   float64
#  4   bank_ret           2015 non-null   float64
#  5   relative_strength  2015 non-null   float64
#  6   breadth_signal     2015 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 125.9+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"])
df = df.set_index("Date")
